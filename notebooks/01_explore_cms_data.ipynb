# %%
import uproot
import sys
import numpy as np

print(sys.executable)

file = uproot.open(
   "../data/37E38CDA-3DD0-F844-A520-4FDF132B3A43.root"
)

print(file.keys())

events = file["Events"]

type(events)

events.num_entries
events.keys()

muon_branches = [
    branch
    for branch in events.keys()
    if "Muon" in branch
]

muon_branches

imp_muon_branches = [
    "nMuon",
    "Muon_pt",
    "Muon_eta",
    "Muon_phi",
    "Muon_mass",
    "Muon_charge"
]

for branch in imp_muon_branches:
    print(branch, "→", branch in events.keys())

n_muons = events["nMuon"].array(entry_stop=1000)
n_muons

muon_pt = events["Muon_pt"].array(entry_stop=1000)
muon_pt

for i in range(len(n_muons)):
    if n_muons[i] >= 2:
        print("First event with at least 2 muons:", i)
        print("Number of muons:", n_muons[i])
        break

event_index = 53
muon_pt = events["Muon_pt"].array(entry_start=event_index, entry_stop=event_index + 1)
muon_eta = events["Muon_eta"].array(entry_start=event_index, entry_stop=event_index + 1)
muon_phi = events["Muon_phi"].array(entry_start=event_index, entry_stop=event_index + 1)
muon_mass = events["Muon_mass"].array(entry_start=event_index, entry_stop=event_index + 1)
muon_charge = events["Muon_charge"].array(entry_start=event_index, entry_stop=event_index + 1)

print("Muon pt:", muon_pt)
print("Muon eta:", muon_eta)
print("Muon phi:", muon_phi)
print("Muon mass:", muon_mass)
print("Muon charge:", muon_charge)

muon_charge = events["Muon_charge"].array(entry_stop=1000)

for i in range(len(muon_charge)):
    charges=muon_charge[i]

    if len(muon_charge) >= 2:
        if 1 in charges and -1 in charges:
            print("First event with opposite-charge muons:", i)
            print("Charges:", charges)
            break
# Out:
# c:\Users\ishit\OneDrive\Documents\CERN Project\.venv\Scripts\python.exe
# ['tag;1', 'Events;1', 'LuminosityBlocks;1', 'Runs;1', 'MetaData;1', 'ParameterSets;1']
# nMuon → True
# Muon_pt → True
# Muon_eta → True
# Muon_phi → True
# Muon_mass → True
# Muon_charge → True
# First event with at least 2 muons: 53
# Number of muons: 2
# Muon pt: [[4.91, 3.38]]
# Muon eta: [[0.351, 0.332]]
# Muon phi: [[2.5, -2.09]]
# Muon mass: [[0.106, 0.106]]
# Muon charge: [[-1, 1]]
# First event with opposite-charge muons: 78
# Charges: [-1, 1]
# px =  -3.9336151523354443
# py =  2.938498227550426
# pz =  1.7590162693988898
# Total momentum =  5.215576500829988
# Energy =  5.216653547630893

# %% [markdown]
# # Exploring CMS Open Data
#
# ## Objective
#
# In this notebook, we will inspect the structure of a CMS Open Data ROOT file before performing any physics analysis.
#
# We will learn:
#
# - how ROOT files are structured
# - how Uproot opens ROOT files
# - how to inspect the objects inside a ROOT file
# - how to identify the relevant TTree
# - how to inspect its branches
# - how CMS event data is represented in Python
#
# The physics analysis will be performed in later notebooks.
